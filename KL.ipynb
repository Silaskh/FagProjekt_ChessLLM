# %%
from evaluation_pipeline_copy import*
from variables import*
from plot_functions import*
from scipy.special import rel_entr

# %%
x_grid1, kde_values_random_1350, x_grid2, kde_values_ensemble_1350 = distribution_plot(score_difference_random_1350, score_difference_ensemble_1350, label1= "Random", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_random_1800, x_grid2, kde_values_ensemble_1800 = distribution_plot(score_difference_random_1800, score_difference_ensemble_1800, label1= "Random", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_random_2250, x_grid2, kde_values_ensemble_2250 = distribution_plot(score_difference_random_2250, score_difference_ensemble_2250, label1= "Random", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_random_2700, x_grid2, kde_values_ensemble_2700 = distribution_plot(score_difference_random_2700, score_difference_ensemble_2700, label1= "Random", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_random_3150, x_grid2, kde_values_ensemble_3150 = distribution_plot(score_difference_random_3150, score_difference_ensemble_3150, label1= "Random", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_1350, x_grid2, kde_values_ensemble_1350 = distribution_plot(score_difference_3_1350, score_difference_ensemble_1350, label1= "Llama3", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_1800, x_grid2, kde_values_ensemble_1800 = distribution_plot(score_difference_3_1800, score_difference_ensemble_1800, label1= "Llama3", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_2250, x_grid2, kde_values_ensemble_2250 = distribution_plot(score_difference_3_2250, score_difference_ensemble_2250, label1= "Llama3", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_2700, x_grid2, kde_values_ensemble_2700 = distribution_plot(score_difference_3_2700, score_difference_ensemble_2700, label1= "Llama3", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_3150, x_grid2, kde_values_ensemble_3150 = distribution_plot(score_difference_3_3150, score_difference_ensemble_3150, label1= "Llama3", label2 = "Ensemble")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_1350, x_grid2, kde_values_random_1350 = distribution_plot(score_difference_3_1350, score_difference_random_1350, label1= "Llama3", label2 = "Random")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_1800, x_grid2, kde_values_random_1800 = distribution_plot(score_difference_3_1800, score_difference_random_1800, label1= "Llama3", label2 = "Random")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_2250, x_grid2, kde_values_random_2250 = distribution_plot(score_difference_3_2250, score_difference_random_2250, label1= "Llama3", label2 = "Random")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_2700, x_grid2, kde_values_random_2700 = distribution_plot(score_difference_3_2700, score_difference_random_2700, label1= "Llama3", label2 = "Random")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_3150, x_grid2, kde_values_random_3150 = distribution_plot(score_difference_3_3150, score_difference_random_3150, label1= "Llama3", label2 = "Random")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x_grid1, kde_values_3_1350, x_grid2, kde_values_2_1350 = distribution_plot(score_difference_3_1350, score_difference_2_1350, label1= "Llama3", label2 = "Llama2")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
kde_values_3 = [kde_values_3_1350, kde_values_3_1800, kde_values_3_2250, kde_values_3_2700, kde_values_3_3150]
kde_values_random = [kde_values_random_1350, kde_values_random_1800, kde_values_random_2250, kde_values_random_2700, kde_values_random_3150]
kde_values_ensemble = [kde_values_ensemble_1350, kde_values_ensemble_1800, kde_values_ensemble_2250, kde_values_ensemble_2700, kde_values_ensemble_3150]


def KL_divergence_list(p, q):
    return [sum(rel_entr(p[i], q[i])) for i in range(len(p))]

KL_3_random = KL_divergence_list(kde_values_random, kde_values_3)
KL_3_ensemble = KL_divergence_list(kde_values_ensemble, kde_values_3)
KL_ensemble_random = KL_divergence_list(kde_values_random, kde_values_ensemble)

KL_3_random, KL_3_ensemble, KL_ensemble_random
# Out:
# ([0.010052777147479146,
#   0.009976606216503724,
#   0.014339318675272817,
#   0.010113137176005002,
#   0.006968429614284072],
#  [0.03189120781076442,
#   0.031410192549114646,
#   0.019279115810620872,
#   0.03188441123734323,
#   0.011149448466408024],
#  [0.008493423170222234,
#   0.008003271741175877,
#   0.004232304145577919,
#   0.008268276673399803,
#   0.004421237349976807])
