# %%
from evaluation_pipeline_copy import*
from variables import*
from plot_functions import*

# %%
x_grid1, kde_values_random, x_grid2, kde_values_ensemble = distribution_plot(score_difference_ensemble_1350, score_difference_ensemble_1350, label1= "Random", label2 = "Ensemble")
x_grid1, kde_values_random, x_grid2, kde_values_ensemble = distribution_plot(score_difference_ensemble_1800, score_difference_ensemble_1800, label1= "Random", label2 = "Ensemble")
x_grid1, kde_values_random, x_grid2, kde_values_ensemble = distribution_plot(score_difference_ensemble_2250, score_difference_ensemble_2250, label1= "Random", label2 = "Ensemble")
x_grid1, kde_values_random, x_grid2, kde_values_ensemble = distribution_plot(score_difference_ensemble_2700, score_difference_ensemble_2700, label1= "Random", label2 = "Ensemble", color1 = "blue")
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
