# %% [markdown]
# <h1> Ollama Testing File </h1>
# Python 3.10.8 <br>
# Ollama installation guide and code snippets: https://pypi.org/project/ollama/

# %%
import sys
import ollama
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import levene
print(sys.executable)
# Out:
# c:\Users\nunni\miniconda3\envs\venv-fagprojekt\python.exe

# %%
#In ollama terminal: ollama run llama2
response = ollama.chat(model='llama2', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])

# %%
# Generate example data for 10 groups
np.random.seed(0)
data = {
    'Group1': np.random.normal(loc=10, scale=2, size=100),
    'Group2': np.random.normal(loc=15, scale=3, size=100),
    'Group3': np.random.normal(loc=20, scale=4, size=100),
    'Group4': np.random.normal(loc=25, scale=2.5, size=100),
    'Group5': np.random.normal(loc=30, scale=3.5, size=100),
    'Group6': np.random.normal(loc=35, scale=2.2, size=100),
    'Group7': np.random.normal(loc=40, scale=3.8, size=100),
    'Group8': np.random.normal(loc=45, scale=4.2, size=100),
    'Group9': np.random.normal(loc=50, scale=3.0, size=100),
    'Group10': np.random.normal(loc=55, scale=2.7, size=100),
}

# Convert data to a DataFrame
df = pd.DataFrame(data)

# Perform Levene's test for equality of variances
levene_stat1, p_value1 = levene(
    df['Group1'], df['Group2']
)

levene_stat2, p_value2 = levene(
    df['Group2'], df['Group3']
)

levene_stat3, p_value3 = levene(
    df['Group3'], df['Group4']
)

print(f"Levene's test statistic: {levene_stat1}")
print(f"p-value: {p_value1}")

print(f"Levene's test statistic: {levene_stat2}")
print(f"p-value: {p_value2}")

print(f"Levene's test statistic: {levene_stat3}")
print(f"p-value: {p_value3}")

# Plot box plots to visualize the data distributions
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.title('Box Plot Comparison of 10 Groups')
plt.xlabel('Groups')
plt.ylabel('Values')
plt.show()
# Out:
# Levene's test statistic: 24.90813960725184
# p-value: 1.3137532206442386e-06
# Levene's test statistic: 1.3069575210777202
# p-value: 0.2543266246645759
# Levene's test statistic: 16.270299704969382
# p-value: 7.837322264932633e-05
