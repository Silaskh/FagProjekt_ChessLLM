# %%
import matplotlib.pyplot as plt
from evaluation_pipeline_copy import *
from plot_functions import *

# %%
data_2 = [r"model_outputs\2_25.txt",r"model_outputs\2_50.txt",r"model_outputs\2_75.txt",r"model_outputs\2_100.txt"]

p_2 = p_list(data_2)
p_2
# Out:
# [0, 1.0, 1.0, 1.0, 1.0]

# %%
data_3 = [r"model_outputs\3_25.txt",r"model_outputs\3_50.txt",r"model_outputs\3_75.txt",r"model_outputs\3_100.txt"]

p_3 = p_list(data_3)
p_3
# Out:
# [0,
#  0.9900990099009901,
#  0.9900990099009901,
#  0.9900990099009901,
#  0.9405940594059405]

# %%
# bar_plot(categories, p_2, p_3, 101, color1= "teal", color2="turquoise")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 bar_plot(categories, p_2, p_3, 101, color1= "teal", color2="turquoise")
#
# File c:\Users\nunni\OneDrive\Skrivebord\Fagprojekt\FagProjekt_ChessLLM\plot_functions.py:14, in bar_plot(categories, p1, p2, N, xlabel, ylabel, title, label1, label2, width, color1, color2)
#      12 # Create the bar plot
#      13 plt.figure(figsize=(10, 6))
# ---> 14 bars1 = plt.bar(positions1, [p*N for p in p1], color=color1, width=width, label=label1)
#      15 bars2 = plt.bar(positions2, [p*N for p in p2], color=color2, width=width, label=label2)
#      17 # Add percentage labels on top of each bar
#
# File c:\Users\nunni\miniconda3\envs\venv-fagprojekt\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
# ...

# %%
bar_plot(['0','25','50','75','100'], [0,91/101,97/101,92/101], [0,31/101,48/101,42/101], 101, title="Number of first index chosen", ylabel="Number of index0 chosen", color1= "teal", color2="turquoise")

# %%
def get_moves(data):
    moves = []
    with open(data) as f:
        for line in f:
            inx, move = line.split(":")
            if move != " None\n":
                move = move[1:-1]
                moves.append(move)
            else:
                moves.append(None)
    return moves

# %%
moves_2 = get_moves(r"model_outputs\2_100.txt")
moves_3 = get_moves(r"model_outputs\3_100_ekstra.txt")

# %%
categories = ['Below 25%',r'25%-50%', r'50%-75%', 'Above 75%']

counts_2 = percentile_distribution(moves_2,df)

# %%
bar_plot(categories, counts_random, counts_2, 101, 'Percentile', 'Number of Moves','Distribution of Moves by Percentile')

# %%
counts_3 = percentile_distribution(moves_3,df)

# %%
counts_3
# Out:
# array([8., 7., 5., 8.])

# %%
bar_plot(categories, counts_2, counts_3, 101, 'Percentile', 'Number of Moves','Distribution of Moves by Percentile')
