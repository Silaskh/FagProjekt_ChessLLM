# %%
import matplotlib.pyplot as plt
from evaluation_pipeline_copy import *
from plot_functions import *

# %%
N = 1000
legal_moves = 990
illegal_moves = 10

# Data for plotting
categories = ['Legal Moves', 'Illegal Moves']
counts = [legal_moves, illegal_moves]

bar_plot(categories, counts, N)

# %%
moves = generate_synthetic_data_dict(10,1,df,100)
N = len(moves)

# Data for plotting
categories = ['Above 75%', r'50%-75%', r'25%-50%', 'Below 25%']
counts = percentile_distribution(moves,df)

bar_plot(categories, counts, N)
